# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://llmchqfhvdwpop:8f6b6899b24221c36bc979822c407c31bd099e3259c5d4f6682d63d993276d3f@ec2-34-230-167-186.compute-1.amazonaws.com:5432/dcoppvn70vslf9'

eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Survey" order by id desc;''',eng).head(10)
# Out:
#    id                             survey_id
# 0  10  b77338ab-5ff6-455b-899f-5f38306ff820
# 1   9  1e5bdd2a-2fdf-4db4-bdc9-0bcf0b95e033
# 2   8  935c253c-9d6d-4eec-9ee1-13d8966204e6
# 3   7  612ec5f1-5307-489f-a62c-a96ea0098bc4
# 4   6  09aef30e-7bd8-4396-ab58-e119f9232c4d
# 5   5  0ca2c865-4c02-4270-ad88-37b86c6cb57e
# 6   4  5ad0d237-dd5f-49b5-b902-b114625eef5c
# 7   3  36e47be8-8334-4f68-a36b-f7fc5e95230a
# 8   2  ebeb66a3-9d6a-4357-bc5b-86000c31884b
# 9   1  c636e027-cc78-4bcf-8b09-23972ac6b7a6

# %%
pd.read_sql('''select * from "Interaction" order by id desc;''',eng).head(10)
# Out:
#     id annotation_id action_type value               timestamp practice_round
# 0  694           139      submit  None 2022-02-07 07:43:38.522          False
# 1  693           139   elevation     2 2022-02-07 07:43:37.723          False
# 2  692           139     azimuth   271 2022-02-07 07:43:37.043          False
# 3  691           139  play audio  None 2022-02-07 07:43:35.590          False
# 4  690           138      submit  None 2022-02-07 07:43:34.955          False
# 5  689           138   elevation    -2 2022-02-07 07:43:33.858          False
# 6  688           138     azimuth     4 2022-02-07 07:43:32.973          False
# 7  687           138  play audio  None 2022-02-07 07:43:31.356          False
# 8  686           137      submit  None 2022-02-07 07:43:30.721          False
# 9  685           137   elevation     3 2022-02-07 07:43:30.042          False

# %%
pd.read_sql('''select * from "Annotation" order by id desc;''',eng).head(10)
# Out:
#     id                             survey_id  recording_id user_note  \
# 0  139  b77338ab-5ff6-455b-899f-5f38306ff820            45
# 1  138  b77338ab-5ff6-455b-899f-5f38306ff820             1
# 2  137  b77338ab-5ff6-455b-899f-5f38306ff820            45
# 3  136  b77338ab-5ff6-455b-899f-5f38306ff820             0
# 4  135  b77338ab-5ff6-455b-899f-5f38306ff820             0
# 5  134  b77338ab-5ff6-455b-899f-5f38306ff820            45
# 6  133  b77338ab-5ff6-455b-899f-5f38306ff820            14
# 7  132  b77338ab-5ff6-455b-899f-5f38306ff820            14
# 8  131  b77338ab-5ff6-455b-899f-5f38306ff820            29
# 9  130  b77338ab-5ff6-455b-899f-5f38306ff820            41
#
#   practice_round
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False

# %%
pd.read_sql('''select * from "Location" order by id desc;''',eng).head(10)
# Out:
#     id annotation_id  azimuth  elevation practice_round
# 0  117           117      316         34           True
# 1  116           116      106          0           True
# 2  115           115       69          0           True
# 3  114           114      269          0           True
# 4  113           113      267          6          False
# 5  112           112      273          4          False
# 6  111           111       10          1          False
# 7  110           110       91         -2          False
# 8  109           109       21         13          False
# 9  108           108      273          4          False

# %%
pd.read_sql('''select * from "Recording" order by group_id asc''',eng)
# Out:
#                                         file_name  recording_id  group_id  \
# 0       gaussian_rec_7_azimuth_0_elevation_60.wav             7         1
# 1    gaussian_rec_34_azimuth_180_elevation_30.wav            34         1
# 2    gaussian_rec_47_azimuth_270_elevation_30.wav            47         1
# 3     gaussian_rec_26_azimuth_150_elevation_0.wav            26         1
# 4   gaussian_rec_21_azimuth_120_elevation_-45.wav            21         1
# 5    gaussian_rec_55_azimuth_330_elevation_30.wav            55         1
# 6    gaussian_rec_33_azimuth_180_elevation_15.wav            33         1
# 7      gaussian_rec_0_azimuth_0_elevation_-45.wav             0         2
# 8   gaussian_rec_45_azimuth_270_elevation_-15.wav            45         2
# 9   gaussian_rec_29_azimuth_180_elevation_-45.wav            29         2
# 10     gaussian_rec_1_azimuth_0_elevation_-30.wav             1         2
# 11    gaussian_rec_46_azimuth_270_elevation_0.wav            46         2
# ...
