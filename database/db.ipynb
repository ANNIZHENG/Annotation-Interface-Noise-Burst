# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://llmchqfhvdwpop:8f6b6899b24221c36bc979822c407c31bd099e3259c5d4f6682d63d993276d3f@ec2-34-230-167-186.compute-1.amazonaws.com:5432/dcoppvn70vslf9'
pd.options.display.max_rows = 999

eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Survey" order by id desc;''',eng).head(1)
# Out:
#    id                             survey_id
# 0  34  a9f772e1-5385-4f1d-a845-6b741e0a1d05

# %%
pd.read_sql('''select * from "Annotation" where survey_id = 'a9f772e1-5385-4f1d-a845-6b741e0a1d05' order by id;''',eng).head(28 + 7)
# Out:
#      id                             survey_id  recording_id  \
# 0   201  a9f772e1-5385-4f1d-a845-6b741e0a1d05            19
# 1   202  a9f772e1-5385-4f1d-a845-6b741e0a1d05            30
# 2   203  a9f772e1-5385-4f1d-a845-6b741e0a1d05            17
# 3   204  a9f772e1-5385-4f1d-a845-6b741e0a1d05            20
# 4   205  a9f772e1-5385-4f1d-a845-6b741e0a1d05            52
# 5   206  a9f772e1-5385-4f1d-a845-6b741e0a1d05            37
# 6   207  a9f772e1-5385-4f1d-a845-6b741e0a1d05            10
# 7   208  a9f772e1-5385-4f1d-a845-6b741e0a1d05            24
# 8   209  a9f772e1-5385-4f1d-a845-6b741e0a1d05            53
# 9   210  a9f772e1-5385-4f1d-a845-6b741e0a1d05            53
# 10  211  a9f772e1-5385-4f1d-a845-6b741e0a1d05            32
# 11  212  a9f772e1-5385-4f1d-a845-6b741e0a1d05            24
# 12  213  a9f772e1-5385-4f1d-a845-6b741e0a1d05            22
# 13  214  a9f772e1-5385-4f1d-a845-6b741e0a1d05            22
# 14  215  a9f772e1-5385-4f1d-a845-6b741e0a1d05            13
# ...

# %%
pd.read_sql('''select * from "Interaction" order by id desc;''',eng).head(200)
# Out:
#        id annotation_id         action_type value               timestamp  \
# 0    1193           235              submit  None 2022-02-12 00:25:57.933
# 1    1192           235           elevation     2 2022-02-12 00:25:57.317
# 2    1191           235             azimuth    61 2022-02-12 00:25:56.602
# 3    1190           235          play audio  None 2022-02-12 00:25:54.568
# 4    1189           234              submit  None 2022-02-12 00:25:53.899
# 5    1188           234           elevation     6 2022-02-12 00:25:53.284
# 6    1187           234             azimuth    85 2022-02-12 00:25:52.350
# 7    1186           234          play audio  None 2022-02-12 00:25:50.716
# 8    1185           233              submit  None 2022-02-12 00:25:50.081
# 9    1184           233           elevation    -2 2022-02-12 00:25:49.416
# 10   1183           233             azimuth   271 2022-02-12 00:25:48.568
# 11   1182           233          play audio  None 2022-02-12 00:25:47.099
# ...

# %%
pd.read_sql('''select * from "Location" order by id desc;''',eng).head(100)
# Out:
#      id annotation_id  azimuth  elevation practice_round
# 0   235           235       61          2          False
# 1   234           234       85          6          False
# 2   233           233      271         -2          False
# 3   232           232      299          7          False
# 4   231           231      293          4          False
# 5   230           230      271          2          False
# 6   229           229      357          4          False
# 7   228           228      318          3          False
# 8   227           227       91          1          False
# 9   226           226      359          1          False
# 10  225           225       60          2          False
# 11  224           224      273         -2          False
# 12  223           223      311         11          False
# 13  222           222      286         -1          False
# 14  221           221      271          0          False
# ...

# %%
pd.read_sql('''select * from "Recording" order by group_id asc''',eng)
# Out:
#                                         file_name  recording_id  group_id  \
# 0   gaussian_rec_21_azimuth_120_elevation_-45.wav            21         1
# 1       gaussian_rec_7_azimuth_0_elevation_60.wav             7         1
# 2    gaussian_rec_34_azimuth_180_elevation_30.wav            34         1
# 3    gaussian_rec_47_azimuth_270_elevation_30.wav            47         1
# 4    gaussian_rec_33_azimuth_180_elevation_15.wav            33         1
# 5    gaussian_rec_55_azimuth_330_elevation_30.wav            55         1
# 6     gaussian_rec_26_azimuth_150_elevation_0.wav            26         1
# 7    gaussian_rec_14_azimuth_60_elevation_-15.wav            14         2
# 8     gaussian_rec_41_azimuth_240_elevation_0.wav            41         2
# 9     gaussian_rec_46_azimuth_270_elevation_0.wav            46         2
# 10     gaussian_rec_1_azimuth_0_elevation_-30.wav             1         2
# 11     gaussian_rec_0_azimuth_0_elevation_-45.wav             0         2
# ...

# %%
pd.read_sql('''select * from "Recording" where recording_id = 24''',eng)
# Out:
#                                       file_name  recording_id  group_id  \
# 0  gaussian_rec_24_azimuth_120_elevation_30.wav            24         6
#
#    user_num_annotation  group_num_annotation
# 0                    5                     3
