# %%
# Noise Bursts Annotation Interface

import pandas as pd
from sqlalchemy import *

# db_path = 'postgresql://llmchqfhvdwpop:8f6b6899b24221c36bc979822c407c31bd099e3259c5d4f6682d63d993276d3f@ec2-34-230-167-186.compute-1.amazonaws.com:5432/dcoppvn70vslf9'
db_path = 'postgresql://pwoaklebhndrfv:f706b27914474556bdf8a647270a0169bedad42f4df75194e949709d5b283953@ec2-50-19-32-96.compute-1.amazonaws.com:5432/d4m9cqbfljjaus'

pd.options.display.max_rows = 1001

eng = create_engine(db_path)

# %%
pd.read_sql('''select count(*) from "Survey" where completed is true;''',eng)
# Out:
#    count
# 0     64

# %%
pd.read_sql('''select * from "Survey" where recording_group_id = 4;''',eng)
# Out:
#     id                             survey_id approved  completed  \
# 0  242  f1a36cd7-fa02-49c5-b185-00047605c657     True       True
# 1  244  593be54a-178c-4cc5-b46f-4ba4e9230447     True       True
# 2  415  bc40f535-4d03-4bfb-b58d-f47f175446aa     True       True
# 3  517  02774846-e1e6-4f66-b418-9184e443606e     True       True
# 4  617  5a4ded17-e053-415b-98cb-845864135d47     None       True
# 5  666  ccc431cc-002f-47bb-834d-f537336e0c3f     None       True
# 6  739  0918357b-4d74-4659-9f5f-0739ae28e5a5     None       True
# 7  744  b9003bd6-3aa5-4dae-b8bb-91bf221c4900     None       True
# 8  743  f4549122-d4e6-4983-bbe5-bb1eb41ea6ac     None       True
#
#    recording_group_id
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# 5                   4
# 6                   4
# 7                   4
# 8                   4

# %%
pd.read_sql('''select * from "Interaction" where  annotation_id = '2319' order by id asc''',eng).head(1)
# Out:
#       id annotation_id         action_type value               timestamp  \
# 0  18075          2319  agree consent form  None 2022-02-19 05:53:46.407
#
#    practice_round
# 0           False

# %%
pd.read_sql('''select * from "Interaction" where  annotation_id = '2324' ''',eng).head(1)
# Out:
#       id annotation_id         action_type value               timestamp  \
# 0  18076          2324  agree consent form  None 2022-02-19 05:53:32.595
#
#    practice_round
# 0           False

# %%
pd.read_sql('''select * from "Location" order by id desc''',eng).head(300)
# Out:
#        id annotation_id  azimuth  elevation  practice_round
# 0    1121          1121      267         -2           False
# 1    1120          1120      270          1           False
# 2    1119          1119      270          0           False
# 3    1118          1118      266         -2           False
# 4    1117          1117      179         -4           False
# 5    1116          1116      269         -1           False
# 6    1115          1115       94          0           False
# 7    1114          1114      272         -2           False
# 8    1113          1113      179          0           False
# 9    1112          1112       91          0           False
# 10   1111          1111      270         -1           False
# 11   1110          1110      268          0           False
# 12   1109          1109       92         -2           False
# 13   1108          1108       89         -3           False
# 14   1107          1107      267          0           False
# ...

# %%
pd.read_sql('''select * from "Interaction" order by id desc''',eng).head(300)
# Out:
#        id                         annotation_id         action_type value  \
# 0    6820                                   834   submit annotation  None
# 1    6819                                   834           elevation     0
# 2    6818                                   834             azimuth    91
# 3    6817                                   834          play audio  None
# 4    6816                                   834  agree consent form  None
# 5    6815  23281bbb-f026-4121-8b07-26bb4cc67639  agree consent form  None
# 6    6814  5c982745-5209-41e0-92ac-20a67cb5a2cb  agree consent form  None
# 7    6813  4c760db2-5b84-4c72-ac84-65fe49659aa8  agree consent form  None
# 8    6812  c7fcf55a-94b2-4748-ae0a-f77e8d40aea5  agree consent form  None
# 9    6811  edbd2e1a-57e4-4e51-8b4f-744ce5bb2fc6  agree consent form  None
# 10   6810  d78d8f6a-ed8e-4f65-8a2a-d2a4c697374f  agree consent form  None
# 11   6809  2729e313-1b8b-41fc-8004-f63dcda5b6ad          play audio  None
# ...

# %%
pd.read_sql('''select * from "Recording" order by group_id''',eng)
# Out:
#                                         file_name  recording_id  group_id  \
# 0     gaussian_rec_26_azimuth_150_elevation_0.wav            26         1
# 1   gaussian_rec_21_azimuth_120_elevation_-45.wav            21         1
# 2    gaussian_rec_55_azimuth_330_elevation_30.wav            55         1
# 3    gaussian_rec_33_azimuth_180_elevation_15.wav            33         1
# 4    gaussian_rec_47_azimuth_270_elevation_30.wav            47         1
# 5    gaussian_rec_34_azimuth_180_elevation_30.wav            34         1
# 6       gaussian_rec_7_azimuth_0_elevation_60.wav             7         1
# 7   gaussian_rec_45_azimuth_270_elevation_-15.wav            45         2
# 8    gaussian_rec_14_azimuth_60_elevation_-15.wav            14         2
# 9      gaussian_rec_0_azimuth_0_elevation_-45.wav             0         2
# 10     gaussian_rec_1_azimuth_0_elevation_-30.wav             1         2
# 11    gaussian_rec_46_azimuth_270_elevation_0.wav            46         2
# ...
