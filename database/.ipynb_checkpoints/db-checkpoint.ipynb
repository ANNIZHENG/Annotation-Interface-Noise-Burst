# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://llmchqfhvdwpop:8f6b6899b24221c36bc979822c407c31bd099e3259c5d4f6682d63d993276d3f@ec2-34-230-167-186.compute-1.amazonaws.com:5432/dcoppvn70vslf9'
eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Survey";''',eng).head(10)
# Out:
#    id                             survey_id
# 0   1  c636e027-cc78-4bcf-8b09-23972ac6b7a6

# %%
pd.read_sql('''select * from "Annotation";''',eng).head(10)
# Out:
#    id                             survey_id  recording_id user_note
# 0   1  c636e027-cc78-4bcf-8b09-23972ac6b7a6            41
# 1   2  c636e027-cc78-4bcf-8b09-23972ac6b7a6            14
# 2   3  c636e027-cc78-4bcf-8b09-23972ac6b7a6             0
# 3   4  c636e027-cc78-4bcf-8b09-23972ac6b7a6             1
# 4   5  c636e027-cc78-4bcf-8b09-23972ac6b7a6            29
# 5   6  c636e027-cc78-4bcf-8b09-23972ac6b7a6            14
# 6   7  c636e027-cc78-4bcf-8b09-23972ac6b7a6            45
# 7   8  c636e027-cc78-4bcf-8b09-23972ac6b7a6            29
# 8   9  c636e027-cc78-4bcf-8b09-23972ac6b7a6            41
# 9  10  c636e027-cc78-4bcf-8b09-23972ac6b7a6             1

# %%
pd.read_sql('''select * from "Recording"''',eng).head(10)
# Out:
#                                        file_name  recording_id  group_id  \
# 0  gaussian_rec_45_azimuth_270_elevation_-15.wav            45         2
# 1     gaussian_rec_1_azimuth_0_elevation_-30.wav             1         2
# 2    gaussian_rec_46_azimuth_270_elevation_0.wav            46         2
# 3    gaussian_rec_41_azimuth_240_elevation_0.wav            41         2
# 4   gaussian_rec_14_azimuth_60_elevation_-15.wav            14         2
# 5     gaussian_rec_0_azimuth_0_elevation_-45.wav             0         2
# 6  gaussian_rec_29_azimuth_180_elevation_-45.wav            29         2
# 7    gaussian_rec_19_azimuth_90_elevation_15.wav            19         3
# 8  gaussian_rec_30_azimuth_180_elevation_-30.wav            30         3
# 9   gaussian_rec_17_azimuth_90_elevation_-30.wav            17         3
#
#    user_num_annotation  group_num_annotation
# 0                    4                     0
# 1                    4                     0
# 2                    4                     0
# 3                    4                     0
# 4                    4                     0
# 5                    4                     0
# 6                    4                     0
# 7                    0                     0
# 8                    0                     0
# 9                    0                     0

# %%
pd.read_sql('''select * from "Location";''',eng).head(10)
# Out:
#    id annotation_id  azimuth  elevation
# 0   1             1      269          4
# 1   2             2       92         -3
# 2   3             3      179          4
# 3   4             4      179         -1
# 4   5             5      134          6
# 5   6             6       89          5
# 6   7             7      273         -2
# 7   8             8      168          1
# 8   9             9      268         12
# 9  10            10       17        -15

# %%
pd.read_sql('''select * from "Interaction";''',eng).head(10)
# Out:
#    id annotation_id action_type value               timestamp
# 0   1             1  play audio  None 2022-02-02 16:18:39.507
# 1   2             1     azimuth   269 2022-02-02 16:18:40.835
# 2   3             1   elevation     4 2022-02-02 16:18:41.460
# 3   4             1      submit  None 2022-02-02 16:18:42.223
# 4   5             2  play audio  None 2022-02-02 16:18:42.957
# 5   6             2     azimuth    92 2022-02-02 16:18:44.576
# 6   7             2   elevation    -3 2022-02-02 16:18:45.277
# 7   8             2      submit  None 2022-02-02 16:18:45.890
# 8   9             3  play audio  None 2022-02-02 16:18:46.574
# 9  10             3     azimuth   179 2022-02-02 16:18:48.810
